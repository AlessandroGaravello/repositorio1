# %%
import pandas as pd
import matplotlib.pyplot as plt
 
datos = pd.read_csv("casasboston.csv")
#datos = datos[["RM","CRIM", "MEDV", "TOWN", "CHAS", "INDUS", "LSTAT"]]
df = datos[["RM","CRIM", "MEDV", "TOWN", "CHAS"]]
 
df = datos.rename(columns={
	"TOWN":"CIUDAD",
	"CRIM":"INDICE_CRIMEN",	
	"INDUS":"PCT_ZONA_INDUSTRIAL",
	"CHAS":"RIO_CHARLES",
	"RM":"N_HABITACIONES_MEDIO",
	"MEDV":"VALOR_MEDIANO",
	"LSTAT":"PCT_CLASE_BAJA"
})
 
print (df.sample(5))
# Out:
#                 CIUDAD      LON      LAT  VALOR_MEDIANO  INDICE_CRIMEN    ZN  \
# 228             Newton -71.1100  42.1850           46.7        0.29819   0.0
# 319             Quincy -71.0200  42.1510           21.0        0.47547   0.0
# 186            Belmont -71.1115  42.2442           50.0        0.05602   0.0
# 331           Holbrook -71.0115  42.0865           17.1        0.05023  35.0
# 464  Boston Dorchester -71.0450  42.1640           21.4        7.83932   0.0
#
#      PCT_ZONA_INDUSTRIAL  RIO_CHARLES     NOX  N_HABITACIONES_MEDIO   AGE  \
# 228                 6.20            0  0.5040                 7.686  17.0
# 319                 9.90            0  0.5440                 6.113  58.8
# 186                 2.46            0  0.4880                 7.831  53.6
# 331                 6.06            0  0.4379                 5.706  28.4
# 464                18.10            0  0.6550                 6.209  65.4
#
#         DIS  RAD  TAX  PTRATIO       B  PCT_CLASE_BAJA
# 228  3.3751    8  307     17.4  377.51            3.92
# 319  4.0019    4  304     18.4  396.23           12.73
# 186  3.1992    3  193     17.8  392.63            4.45
# 331  6.6407    1  304     16.9  394.02           12.43
# 464  2.9634   24  666     20.2  396.90           13.22

# %% [markdown]
# # Histogramas

# %%
import pandas as pd
import matplotlib.pyplot as plt
 
datos = pd.read_csv("casasboston.csv")
#datos = datos[["RM","CRIM", "MEDV", "TOWN", "CHAS", "INDUS", "LSTAT"]]
df = datos[["RM","CRIM", "MEDV", "TOWN", "CHAS"]]
 
df = datos.rename(columns={
	"TOWN":"CIUDAD",
	"CRIM":"INDICE_CRIMEN",	
	"INDUS":"PCT_ZONA_INDUSTRIAL",
	"CHAS":"RIO_CHARLES",
	"RM":"N_HABITACIONES_MEDIO",
	"MEDV":"VALOR_MEDIANO",
	"LSTAT":"PCT_CLASE_BAJA"
})
 
#plot.hist

df.N_HABITACIONES_MEDIO.plot.hist()
plt.show()

# %% [markdown]
# # Gráfico de dispersión

# %%
import pandas as pd
import matplotlib.pyplot as plt
 
datos = pd.read_csv("casasboston.csv")
#datos = datos[["RM","CRIM", "MEDV", "TOWN", "CHAS", "INDUS", "LSTAT"]]
df = datos[["RM","CRIM", "MEDV", "TOWN", "CHAS"]]
 
df = datos.rename(columns={
	"TOWN":"CIUDAD",
	"CRIM":"INDICE_CRIMEN",	
	"INDUS":"PCT_ZONA_INDUSTRIAL",
	"CHAS":"RIO_CHARLES",
	"RM":"N_HABITACIONES_MEDIO",
	"MEDV":"VALOR_MEDIANO",
	"LSTAT":"PCT_CLASE_BAJA"
})

#plot.scatter

df.plot.scatter(x="INDICE_CRIMEN", y="VALOR_MEDIANO", alpha=0.2)
plt.show()

# %% [markdown]
# # Gráfico de barras

# %%
import pandas as pd
import matplotlib.pyplot as plt
 
datos = pd.read_csv("casasboston.csv")
#datos = datos[["RM","CRIM", "MEDV", "TOWN", "CHAS", "INDUS", "LSTAT"]]
df = datos[["RM","CRIM", "MEDV", "TOWN", "CHAS"]]
 
df = datos.rename(columns={
	"TOWN":"CIUDAD",
	"CRIM":"INDICE_CRIMEN",	
	"INDUS":"PCT_ZONA_INDUSTRIAL",
	"CHAS":"RIO_CHARLES",
	"RM":"N_HABITACIONES_MEDIO",
	"MEDV":"VALOR_MEDIANO",
	"LSTAT":"PCT_CLASE_BAJA"
})
 
#plot.barth

valor_por_ciudad = df.groupby("CIUDAD")["VALOR_MEDIANO"].mean()
valor_por_ciudad.head(10).plot.barh()
plt.show()

# %% [markdown]
# # Diagrama de cajas

# %%
import pandas as pd
import matplotlib.pyplot as plt
 
datos = pd.read_csv("casasboston.csv")
#datos = datos[["RM","CRIM", "MEDV", "TOWN", "CHAS", "INDUS", "LSTAT"]]
df = datos[["RM","CRIM", "MEDV", "TOWN", "CHAS"]]
 
df = datos.rename(columns={
	"TOWN":"CIUDAD",
	"CRIM":"INDICE_CRIMEN",	
	"INDUS":"PCT_ZONA_INDUSTRIAL",
	"CHAS":"RIO_CHARLES",
	"RM":"N_HABITACIONES_MEDIO",
	"MEDV":"VALOR_MEDIANO",
	"LSTAT":"PCT_CLASE_BAJA"
})
 
#boxplot

df["VALOR_CUANTILES"] = pd.qcut(df.VALOR_MEDIANO, 5)
df.boxplot(column="INDICE_CRIMEN", by="VALOR_CUANTILES",
	figsize=(8,6))
plt.show()

# %% [markdown]
# # Gráfico circular

# %%
import pandas as pd
import matplotlib.pyplot as plt
 
datos = pd.read_csv("casasboston.csv")
#datos = datos[["RM","CRIM", "MEDV", "TOWN", "CHAS", "INDUS", "LSTAT"]]
df = datos[["RM","CRIM", "MEDV", "TOWN", "CHAS"]]
 
df = datos.rename(columns={
	"TOWN":"CIUDAD",
	"CRIM":"INDICE_CRIMEN",	
	"INDUS":"PCT_ZONA_INDUSTRIAL",
	"CHAS":"RIO_CHARLES",
	"RM":"N_HABITACIONES_MEDIO",
	"MEDV":"VALOR_MEDIANO",
	"LSTAT":"PCT_CLASE_BAJA"
})
 
#plot.pie

df.RIO_CHARLES.value_counts().plot.pie()
plt.show()
